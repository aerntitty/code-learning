# %%
import os
import pandas as pd
import numpy as np

# %%
os.getcwd()
# Out:
# '/Users/beckyiyeh/Documents/pythonProjects'

# %%
path='/Users/beckyiyeh/Documents/pythonProjects'

sales=pd.read_csv( "sales.csv")
sales['sale_date'] = pd.to_datetime(sales['sale_date'])

# %%
sales['sale_time']=pd.to_datetime(sales['sale_time'])
# Out:
# /var/folders/xb/0d6fwnd11lbfh6b333tqcylh0000gn/T/ipykernel_29926/224586215.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   sales['sale_time']=pd.to_datetime(sales['sale_time'])

# %%
sales.head()
# Out:
#    transactions_id  sale_date           sale_time  customer_id  gender   age  \
# 0              180 2022-11-05 2024-10-11 10:47:00          117    Male  41.0
# 1              522 2022-07-09 2024-10-11 11:00:00           52    Male  46.0
# 2              559 2022-12-12 2024-10-11 10:48:00            5  Female  40.0
# 3             1180 2022-01-06 2024-10-11 08:53:00           85    Male  41.0
# 4             1522 2022-11-14 2024-10-11 08:35:00           48    Male  46.0
#
#    category  quantiy  price_per_unit   cogs  total_sale
# 0  Clothing      3.0           300.0  129.0       900.0
# 1    Beauty      3.0           500.0  145.0      1500.0
# 2  Clothing      4.0           300.0   84.0      1200.0
# 3  Clothing      3.0           300.0  129.0       900.0
# 4    Beauty      3.0           500.0  235.0      1500.0

# %%
sales.set_index('sale_date', inplace= True)
sales
# Out:
#             transactions_id           sale_time  customer_id  gender   age  \
# sale_date
# 2022-11-05              180 2024-10-11 10:47:00          117    Male  41.0
# 2022-07-09              522 2024-10-11 11:00:00           52    Male  46.0
# 2022-12-12              559 2024-10-11 10:48:00            5  Female  40.0
# 2022-01-06             1180 2024-10-11 08:53:00           85    Male  41.0
# 2022-11-14             1522 2024-10-11 08:35:00           48    Male  46.0
# ...                     ...                 ...          ...     ...   ...
# 2022-11-09             1857 2024-10-11 12:15:00          109    Male  60.0
# 2022-09-12              211 2024-10-11 14:02:00           54    Male  42.0
# 2023-10-08              650 2024-10-11 12:41:00           98    Male  55.0
# 2023-11-22             1211 2024-10-11 14:59:00           82    Male  42.0
# 2022-09-23             1650 2024-10-11 16:24:00           89    Male  55.0
#
# ...

# %%
sales['gender']
# Out:
# sale_date
# 2022-11-05      Male
# 2022-07-09      Male
# 2022-12-12    Female
# 2022-01-06      Male
# 2022-11-14      Male
#                ...
# 2022-11-09      Male
# 2022-09-12      Male
# 2023-10-08      Male
# 2023-11-22      Male
# 2022-09-23      Male
# Name: gender, Length: 2000, dtype: object

# %%
sales['total_sale'].mean()
# Out:
# np.float64(456.54481722583876)

# %%
sales['gender']== 'Female'
# Out:
# sale_date
# 2022-11-05    False
# 2022-07-09    False
# 2022-12-12     True
# 2022-01-06    False
# 2022-11-14    False
#               ...
# 2022-11-09    False
# 2022-09-12    False
# 2023-10-08    False
# 2023-11-22    False
# 2022-09-23    False
# Name: gender, Length: 2000, dtype: bool

# %%
female_sales=sales.loc[sales['gender']== 'Female' ,'total_sale'].sum()
female_sales
# Out:
# np.float64(465400.0)

# %%
sales['gender'] == 'Male'
# Out:
# sale_date
# 2022-11-05     True
# 2022-07-09     True
# 2022-12-12    False
# 2022-01-06     True
# 2022-11-14     True
#               ...
# 2022-11-09     True
# 2022-09-12     True
# 2023-10-08     True
# 2023-11-22     True
# 2022-09-23     True
# Name: gender, Length: 2000, dtype: bool

# %%
 males_sales=sales.loc[sales['gender'] == 'Male','total_sale'].sum()
males_sales
# Out:
# np.float64(446320.0)

# %%
sales
# Out:
#             transactions_id           sale_time  customer_id  gender   age  \
# sale_date
# 2022-11-05              180 2024-10-11 10:47:00          117    Male  41.0
# 2022-07-09              522 2024-10-11 11:00:00           52    Male  46.0
# 2022-12-12              559 2024-10-11 10:48:00            5  Female  40.0
# 2022-01-06             1180 2024-10-11 08:53:00           85    Male  41.0
# 2022-11-14             1522 2024-10-11 08:35:00           48    Male  46.0
# ...                     ...                 ...          ...     ...   ...
# 2022-11-09             1857 2024-10-11 12:15:00          109    Male  60.0
# 2022-09-12              211 2024-10-11 14:02:00           54    Male  42.0
# 2023-10-08              650 2024-10-11 12:41:00           98    Male  55.0
# 2023-11-22             1211 2024-10-11 14:59:00           82    Male  42.0
# 2022-09-23             1650 2024-10-11 16:24:00           89    Male  55.0
#
# ...

# %%
sales['total_sale'].max()
# Out:
# np.float64(2000.0)

# %%
sales.loc[sales['total_sale']== '2000',['customer_id','gender']]
# Out:
# Empty DataFrame
# Columns: [customer_id, gender]
# Index: []

# %%
sales['category'].to_frame()
# Out:
#                category
# sale_date
# 2022-11-05     Clothing
# 2022-07-09       Beauty
# 2022-12-12     Clothing
# 2022-01-06     Clothing
# 2022-11-14       Beauty
# ...                 ...
# 2022-11-09  Electronics
# 2022-09-12       Beauty
# 2023-10-08  Electronics
# 2023-11-22       Beauty
# 2022-09-23  Electronics
#
# [2000 rows x 1 columns]

# %%
clothing_sales=sales.loc[sales['category']== 'Clothing' , 'total_sale'].sum()
clothing_sales
# Out:
# np.float64(311070.0)

# %%
electronic_sales=sales.loc[sales['category']== 'Electronics' , 'total_sale'].sum()
electronic_sales
# Out:
# np.float64(313810.0)

# %%
beauty_sales=sales.loc[sales['category']== 'Beauty' , 'total_sale'].sum()
beauty_sales
# Out:
# np.float64(286840.0)

# %%
import matplotlib.pyplot as plt

# %%
sales['gender'].value_counts()
# Out:
# gender
# Female    1020
# Male       980
# Name: count, dtype: int64

# %%
ax=sales['category'].value_counts().plot(kind='bar', figsize=(14,6))
ax.set_ylabel('category')
# Out:
# Text(0, 0.5, 'category')

# %%
sales['taxes']=sales['total_sale']*0.05
sales['taxes'].head()
# Out:
# sale_date
# 2022-11-05    45.0
# 2022-07-09    75.0
# 2022-12-12    60.0
# 2022-01-06    45.0
# 2022-11-14    75.0
# Name: taxes, dtype: float64

# %%
sales
# Out:
#             transactions_id           sale_time  customer_id  gender   age  \
# sale_date
# 2022-11-05              180 2024-10-11 10:47:00          117    Male  41.0
# 2022-07-09              522 2024-10-11 11:00:00           52    Male  46.0
# 2022-12-12              559 2024-10-11 10:48:00            5  Female  40.0
# 2022-01-06             1180 2024-10-11 08:53:00           85    Male  41.0
# 2022-11-14             1522 2024-10-11 08:35:00           48    Male  46.0
# ...                     ...                 ...          ...     ...   ...
# 2022-11-09             1857 2024-10-11 12:15:00          109    Male  60.0
# 2022-09-12              211 2024-10-11 14:02:00           54    Male  42.0
# 2023-10-08              650 2024-10-11 12:41:00           98    Male  55.0
# 2023-11-22             1211 2024-10-11 14:59:00           82    Male  42.0
# 2022-09-23             1650 2024-10-11 16:24:00           89    Male  55.0
#
# ...

# %%
df= pd.Series({'Beauty' : (beauty_sales), 'Clothing' : (clothing_sales), 'Electronics':(electronic_sales)})
df
# Out:
# Beauty         286840.0
# Clothing       311070.0
# Electronics    313810.0
# dtype: float64

# %%
df.columns=['product' ,'total_sales']
df
# Out:
# Beauty         286840.0
# Clothing       311070.0
# Electronics    313810.0
# dtype: float64

# %%
df.plot(kind='bar',figsize=(12,6))
# Out:
# <Axes: >

# %%
df.plot(kind='bar',figsize=(12,6))
# Out:
# <Axes: >

# %%
sales['category'].value_counts().plot(kind='bar',figsize=(12,6))
# Out:
# <Axes: xlabel='category'>

# %%
sales['total_sale'].plot(kind='hist',figsize=(10, 6), title='Sales Trend Over Time')

# 3. Show the plot
plt.ylabel('total_sale')
plt.xlabel('sale_date')
plt.show()

# %%
sales
# Out:
#             transactions_id           sale_time  customer_id  gender   age  \
# sale_date
# 2022-11-05              180 2024-10-11 10:47:00          117    Male  41.0
# 2022-07-09              522 2024-10-11 11:00:00           52    Male  46.0
# 2022-12-12              559 2024-10-11 10:48:00            5  Female  40.0
# 2022-01-06             1180 2024-10-11 08:53:00           85    Male  41.0
# 2022-11-14             1522 2024-10-11 08:35:00           48    Male  46.0
# ...                     ...                 ...          ...     ...   ...
# 2022-11-09             1857 2024-10-11 12:15:00          109    Male  60.0
# 2022-09-12              211 2024-10-11 14:02:00           54    Male  42.0
# 2023-10-08              650 2024-10-11 12:41:00           98    Male  55.0
# 2023-11-22             1211 2024-10-11 14:59:00           82    Male  42.0
# 2022-09-23             1650 2024-10-11 16:24:00           89    Male  55.0
#
# ...

# %%
ax= sales['customer_id'].value_counts().plot(kind='bar' ,figsize=(60,10))

ax.set_ylabel=('visits to the store')
ax.set_xlabel=('customer_id')

# %%
sales['customer_id'].value_counts().to_frame()
# Out:
#              count
# customer_id
# 3               76
# 1               76
# 4               73
# 2               69
# 5               63
# ...            ...
# 36               3
# 34               3
# 45               3
# 128              2
# 123              2
#
# [155 rows x 1 columns]

# %%
female_sales=sales.loc[sales['gender']== 'Female' , 'total_sale'].sum()

# %%
male_sales=sales.loc[sales['gender']== 'Male' , 'total_sale'].sum()
male_sales
# Out:
# np.float64(446320.0)

# %%
gender_stud = pd.Series({'females' : (female_sales) , 'males' :(male_sales)} ,
                        name = "gender_in_relation_to_sales")
gender_stud
# Out:
# females    465400.0
# males      446320.0
# Name: gender_in_relation_to_sales, dtype: float64

# %%
gender_stud.plot(kind='pie', figsize=(6,6))
# Out:
# <Axes: ylabel='gender_in_relation_to_sales'>

# %%
av=sales.loc[sales['gender']== 'Female', 'category'].value_counts()
av.to_frame()
# Out:
#              count
# category
# Clothing       348
# Electronics    340
# Beauty         332

# %%
av.plot(kind='pie' , figsize=(6,6))
# Out:
# <Axes: ylabel='count'>

# %%
n=sales['age'].value_counts().to_frame()
n
# Out:
#       count
# age
# 43.0     62
# 64.0     62
# 57.0     59
# 51.0     59
# 34.0     56
# 62.0     54
# 54.0     54
# 22.0     54
# 42.0     52
# 47.0     52
# 46.0     50
# 23.0     48
# 40.0     47
# 27.0     46
# 50.0     46
# 52.0     44
# 31.0     44
# 35.0     44
# 30.0     44
# 26.0     44
# 20.0     42
# 28.0     42
# 41.0     42
# 18.0     42
# 55.0     42
# 60.0     42
# 19.0     41
# 21.0     40
# 25.0     40
# 32.0     38
# 49.0     38
# 56.0     38
# 38.0     38
# 48.0     36
# 39.0     36
# 61.0     36
# 53.0     34
# 45.0     34
# 63.0     34
# 59.0     34
# 37.0     32
# 29.0     32
# 24.0     30
# 36.0     30
# 44.0     30
# 58.0     26
# 33.0     20

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2000 entries, 2022-11-05 to 2022-09-23
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   transactions_id  2000 non-null   int64
#  1   sale_time        2000 non-null   datetime64[ns]
#  2   customer_id      2000 non-null   int64
#  3   gender           2000 non-null   object
#  4   age              1990 non-null   float64
#  5   category         2000 non-null   object
#  6   quantiy          1997 non-null   float64
#  7   price_per_unit   1997 non-null   float64
#  8   cogs             1997 non-null   float64
#  9   total_sale       1997 non-null   float64
#  10  taxes            1997 non-null   float64
# dtypes: datetime64[ns](1), float64(6), int64(2), object(2)
# memory usage: 187.5+ KB

# %%
sales['sale_time']
# Out:
# sale_date
# 2022-11-05   2024-10-11 10:47:00
# 2022-07-09   2024-10-11 11:00:00
# 2022-12-12   2024-10-11 10:48:00
# 2022-01-06   2024-10-11 08:53:00
# 2022-11-14   2024-10-11 08:35:00
#                      ...
# 2022-11-09   2024-10-11 12:15:00
# 2022-09-12   2024-10-11 14:02:00
# 2023-10-08   2024-10-11 12:41:00
# 2023-11-22   2024-10-11 14:59:00
# 2022-09-23   2024-10-11 16:24:00
# Name: sale_time, Length: 2000, dtype: datetime64[ns]

# %%
sales.shape
# Out:
# (2000, 11)

# %%
sales.describe()
# Out:
#        transactions_id                   sale_time  customer_id          age  \
# count      2000.000000                        2000  2000.000000  1990.000000
# mean       1000.500000  2024-10-11 16:27:44.820000    66.341500    41.343216
# min           1.000000         2024-10-11 06:01:00     1.000000    18.000000
# 25%         500.750000         2024-10-11 11:28:45    24.000000    29.000000
# 50%        1000.500000         2024-10-11 18:16:00    69.000000    42.000000
# 75%        1500.250000         2024-10-11 20:33:00   102.000000    53.000000
# max        2000.000000         2024-10-11 23:00:00   155.000000    64.000000
# std         577.494589                         NaN    44.937185    13.668167
#
#            quantiy  price_per_unit         cogs   total_sale        taxes
# count  1997.000000     1997.000000  1997.000000  1997.000000  1997.000000
# mean      2.512769      180.117677    95.023886   456.544817    22.827241
# ...

# %%
gg= sales.loc[sales['age']==18, 'category'].to_frame()
gg
# Out:
#                category
# sale_date
# 2022-08-26       Beauty
# 2022-09-23       Beauty
# 2022-05-01  Electronics
# 2022-12-10  Electronics
# 2022-10-29     Clothing
# 2022-11-23     Clothing
# 2022-11-04  Electronics
# 2022-07-12  Electronics
# 2023-07-18       Beauty
# 2023-05-01       Beauty
# 2023-01-10  Electronics
# 2023-07-28  Electronics
# 2023-06-01  Electronics
# 2023-03-21       Beauty
# 2023-10-14  Electronics
# 2023-12-08       Beauty
# 2023-07-03     Clothing
# 2023-08-11     Clothing
# 2023-03-22       Beauty
# 2023-04-05       Beauty
# 2023-05-26       Beauty
# 2023-10-17       Beauty
# 2022-02-05  Electronics
# 2023-05-17  Electronics
# 2023-01-15       Beauty
# 2023-03-29       Beauty
# 2023-11-23     Clothing
# 2023-09-01     Clothing
# 2023-12-22     Clothing
# 2022-09-12     Clothing
# 2023-11-25     Clothing
# 2023-09-05     Clothing
# 2022-10-15     Clothing
# 2023-10-04     Clothing
# 2023-09-16     Clothing
# 2022-10-30     Clothing
# 2022-11-28       Beauty
# ...

# %%
gg.value_counts()
# Out:
# category
# Beauty         18
# Clothing       14
# Electronics    10
# Name: count, dtype: int64
